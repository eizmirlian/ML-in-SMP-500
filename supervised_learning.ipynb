# %% [markdown]
# Import necesary packages for project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler 
import matplotlib.pyplot as plt
# !pip install tensorflow
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in c:\users\billi\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (20.9)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (1.50.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (22.10.26)
# Requirement already satisfied: numpy>=1.20 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (1.20.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\billi\anaconda3\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\billi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.36.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\billi\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.25.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\billi\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\billi\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\billi\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.14.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\billi\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\billi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\billi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\billi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\billi\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\billi\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\billi\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\billi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\billi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\billi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\billi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\billi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\billi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\billi\anaconda3\lib\site-packages (from packaging->tensorflow) (2.4.7)

# %% [markdown]
# Import S&P500 historic data as CSV

# %%
ds = pd.read_csv("S&P 500 Historical Data.csv")
df = pd.DataFrame(ds)
print(df.head(5))
arr = np.array(df)
print("DataFrame:")
print(df)
print("Date:")
Date = np.flip(np.transpose(arr[:,np.where(np.array(df.columns) == 'Date')[0]])[0])
Date = pd.to_datetime(Date)
df["Price"] = df["Price"].str.replace(',','')
print(df["Price"])
df["Price"] = df["Price"].astype("float64")
print(Date)
print("Prices:")
#prices = np.flip(np.transpose(arr[:,np.where(np.array(df.columns) == 'Price')[0]])[0])
prices = prices.astype(str)
prices = np.char.replace(prices,',','').astype(float)

print(prices)
# Out:
#          Date     Price      Open      High       Low  Vol. Change %
# 0  10/30/2022  3,759.69  3,873.55  3,913.62  3,758.85   NaN   -3.62%
# 1  10/23/2022  3,901.06  3,770.75  3,906.05  3,741.38   NaN    3.95%
# 2  10/16/2022  3,752.75  3,652.35  3,764.55  3,646.34   NaN    4.74%
# 3  10/09/2022  3,583.07  3,651.20  3,711.73  3,490.00   NaN   -1.55%
# 4  10/02/2022  3,639.66  3,624.07  3,807.35  3,605.60   NaN    1.51%
# DataFrame:
#            Date     Price      Open      High       Low  Vol. Change %
# 0    10/30/2022  3,759.69  3,873.55  3,913.62  3,758.85   NaN   -3.62%
# 1    10/23/2022  3,901.06  3,770.75  3,906.05  3,741.38   NaN    3.95%
# 2    10/16/2022  3,752.75  3,652.35  3,764.55  3,646.34   NaN    4.74%
# 3    10/09/2022  3,583.07  3,651.20  3,711.73  3,490.00   NaN   -1.55%
# 4    10/02/2022  3,639.66  3,624.07  3,807.35  3,605.60   NaN    1.51%
# ..          ...       ...       ...       ...       ...   ...      ...
# 561  01/29/2012  1,344.90  1,316.16  1,345.34  1,300.49   NaN    2.17%
# 562  01/22/2012  1,316.33  1,315.29  1,333.47  1,306.06   NaN    0.07%
# 563  01/15/2012  1,315.38  1,290.22  1,315.49  1,290.22   NaN    2.04%
# 564  01/08/2012  1,289.09  1,277.83  1,296.82  1,274.55   NaN    0.88%
# 565  01/01/2012  1,277.81  1,258.86  1,284.62  1,258.86   NaN    1.61%
#
# [566 rows x 7 columns]
# Date:
# 0      3759.69
# 1      3901.06
# 2      3752.75
# 3      3583.07
# 4      3639.66
#         ...
# 561    1344.90
# 562    1316.33
# 563    1315.38
# 564    1289.09
# 565    1277.81
# Name: Price, Length: 566, dtype: object
# DatetimeIndex(['2012-01-01', '2012-01-08', '2012-01-15', '2012-01-22',
#                '2012-01-29', '2012-02-05', '2012-02-12', '2012-02-19',
#                '2012-02-26', '2012-03-04',
#                ...
#                '2022-08-28', '2022-09-04', '2022-09-11', '2022-09-18',
#                '2022-09-25', '2022-10-02', '2022-10-09', '2022-10-16',
#                '2022-10-23', '2022-10-30'],
#  2818.82 2840.35 2833.28 2850.13 2874.69 2901.52 2871.68 2904.98 2929.67
#  2913.98 2885.57 2767.13 2767.78 2658.69 2723.06 2781.01 2736.27 2632.56
#  2760.17 2633.08 2599.95 2416.62 2485.74 2531.94 2596.26 2670.71 2664.76
#  2706.53 2707.88 2775.6  2792.67 2803.69 2743.07 2822.48 2800.71 2834.4
#  2892.74 2907.41 2905.03 2939.88 2945.64 2881.4  2859.53 2826.06 2752.06
#  2873.34 2886.98 2950.46 2941.76 2990.41 3013.77 2976.61 3025.86 2932.05
#  2918.65 2888.68 2847.11 2926.46 2978.71 3007.39 2992.07 2961.79 2952.01
#  2970.27 2986.2  3022.55 3066.91 3093.08 3120.46 3110.29 3140.98 3145.91
#  3168.8  3221.22 3240.02 3234.85 3265.35 3329.62 3295.47 3225.52 3327.71
#  3380.16 3337.75 2954.22 2972.37 2711.02 2304.92 2541.47 2488.65 2789.82
#  2874.56 2836.74 2830.71 2929.8  2863.7  2955.45 3044.31 3193.93 3041.31
#  3097.74 3009.05 3130.01 3185.04 3224.73 3215.63 3271.12 3351.28 3372.85
#  3397.16 3508.01 3426.96]
# float64

# %% [markdown]
# Make prediction using LSTM model

# %% [markdown]
# Make sure to output to lstm variable as a numpy array of same size as prices

# %%
lstm = np.ones(len(prices))

# %% [markdown]
# Plotted data

# %%
plt.plot(Date,prices,Date, lstm)
# Out:
# [<matplotlib.lines.Line2D at 0x2abeaa10100>,
#  <matplotlib.lines.Line2D at 0x2abeaa41f70>]

# %%
plt.figure(figsize=(15, 8))
plt.title('Stock Prices History')
plt.plot(df['Price'])
plt.xlabel('Date')
plt.ylabel('Prices ($)')
plt.show()

# %%
min_max_scale = MinMaxScaler(feature_range=(0,1))
scaled= min_max_scale.fit_transform(prices.reshape(-1,1))
training = scaled[0: cutoff, :]

x_train = []
y_train = []

for i in range(60, len(training)):
    x_train.append(training[i-60:i, 0])
    y_train.append(training[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
testing = scaled[cutoff-60: , : ]
x_test = []
y_test = prices[cutoff:]

for i in range(60, len(testing)):
    x_test.append(testing[i-60:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
lstm = keras.Sequential()
lstm.add(layers.LSTM(100, return_sequences=True, input_shape=(x_train.shape[1], 1)))
lstm.add(layers.LSTM(100, return_sequences=False))
lstm.add(layers.Dense(25))
lstm.add(layers.Dense(1))
lstm.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 60, 100)           40800
#
#  lstm_23 (LSTM)              (None, 100)               80400
#
#  dense_22 (Dense)            (None, 25)                2525
#
#  dense_23 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 123,751
# Trainable params: 123,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm.compile(optimizer='adam', loss='mean_squared_error')
lstm.fit(x_train, y_train, batch_size= 1, epochs=3)
# Out:
# Epoch 1/3
# 393/393 [==============================] - 21s 46ms/step - loss: 0.0025
# Epoch 2/3
# 393/393 [==============================] - 26s 66ms/step - loss: 0.0013
# Epoch 3/3
# 393/393 [==============================] - 23s 59ms/step - loss: 8.5411e-04

# %%
predictions = lstm.predict(x_test)
predictions = min_max_scale.inverse_transform(predictions)
rmse = np.sqrt(np.mean(predictions - y_test)**2)
rmse
# Out:
# 4/4 [==============================] - 1s 34ms/step
# 2620.92170570036

# %%
data = df.loc[::-1].filter(['Price'])
train = data[:cutoff]
validation = data[cutoff:].copy(deep=True)
validation['Predictions'] = predictions
plt.figure(figsize=(17,9))
plt.title('S&P 500 Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.plot(train)

plt.plot(validation[['Price','Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
